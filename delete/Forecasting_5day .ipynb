# %% [markdown]
# # Load data

# %%
import pandas as pd

df_dataset = pd.read_csv("preprocessed_dataset.csv",index_col=0).drop(columns=["1d_pct_price_var","10d_pct_price_var"])

# %% [markdown]
# # Train - test separation

# %%
df_train = df_dataset.iloc[:-900]
df_test = df_dataset.iloc[-900:]

x_train = df_train.drop(columns=["5d_pct_price_var","observation_date"])
y_train = df_train["5d_pct_price_var"]
x_test = df_test.drop(columns=["5d_pct_price_var","observation_date"])
y_test = df_test["5d_pct_price_var"]

# %% [markdown]
# # Model Hyperparameters Selection

# %%
# # !pip install lightgbm
# from lightgbm import LGBMRegressor
# from sklearn.model_selection import GridSearchCV
# import warnings
# warnings.filterwarnings('ignore', category=FutureWarning)


# estimator = LGBMRegressor(verbose=-1)
# param_grid = {
#     # "n_estimators": [5, 10, 50,100,500],
#     "n_estimators": [5,100,500],
#     "max_depth": [-1,5,10],
#     # "min_child_samples": [5, 10, 20, 50], 
#     "min_child_samples": [30,40,50,100,500], 
#     "learning_rate": [0.01, 0.02,0.05,0.2],
#     "lambda_l2":[0, 1, 2, 3]
# }

# grid_search = GridSearchCV(
#     estimator=estimator,
#     param_grid=param_grid,
#     scoring='r2',
#     cv=4,
#     verbose=1
# )

# grid_search.fit(x_train, y_train)

# print("LGBM")
# print("Best score:", grid_search.best_score_)
# print("Best parameters:", grid_search.best_params_)

# %%
# grid_search.score(x_test,y_test)

# %%
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import make_scorer
import numpy as np
import optuna
from lightgbm import LGBMRegressor
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

# Custom scorer
def sign_accuracy(y_true, y_pred):
    return np.mean(np.sign(y_true) == np.sign(y_pred))

# Make scorer for sklearn
sign_acc_scorer = make_scorer(sign_accuracy, greater_is_better=True)

# Optuna objective
def objective(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 5, 505, step=50),
        "max_depth": trial.suggest_int("max_depth", 5, 10),
        "max_bin": trial.suggest_int("max_bin", 50, 100, step=10),
        "num_leaves": trial.suggest_int("num_leaves", 10, 35, step=5),
        "bagging_freq": trial.suggest_int("bagging_freq", 1, 5),
        "bagging_fraction": trial.suggest_float("bagging_fraction", 0.2, 0.9),
        "feature_fraction": trial.suggest_float("feature_fraction", 0.2, 0.9),
        "min_child_samples": trial.suggest_int("min_child_samples", 20, 100),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.1),
        "lambda_l2": trial.suggest_int("lambda_l2", 0, 10),
        "device": "gpu",
        "verbose": -1,
        "random_state": 0
    }

    model = LGBMRegressor(**params)
    
    # Use cross-validation with custom scorer
    cv = KFold(n_splits=4, shuffle=True, random_state=0)
    scores = cross_val_score(model, x_train, y_train, cv=cv, scoring=sign_acc_scorer, n_jobs=-1)
    return np.mean(scores)

# Run Optuna Study
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=20, show_progress_bar=True)

print("\nLGBM Optuna Results")
print("Best Sign Accuracy score (CV):", study.best_value)
print("Best hyperparameters:", study.best_params)


# LGBM Optuna Results
# Best Sign Accuracy score (CV): 0.5783333333333334
# Out:
# [I 2025-07-04 11:24:05,049] A new study created in memory with name: no-name-2bc179c5-8b53-4ff3-b674-ac501e1deb35
#   0%|          | 0/20 [00:00<?, ?it/s]
# [I 2025-07-04 11:24:13,523] Trial 0 finished with value: 0.5716666666666667 and parameters: {'n_estimators': 505, 'max_depth': 7, 'max_bin': 70, 'num_leaves': 30, 'bagging_freq': 2, 'bagging_fraction': 0.509333287708895, 'feature_fraction': 0.7458296641931426, 'min_child_samples': 25, 'learning_rate': 0.07169243980037304, 'lambda_l2': 9}. Best is trial 0 with value: 0.5716666666666667.
# [I 2025-07-04 11:24:16,667] Trial 1 finished with value: 0.5625 and parameters: {'n_estimators': 105, 'max_depth': 9, 'max_bin': 50, 'num_leaves': 15, 'bagging_freq': 1, 'bagging_fraction': 0.7438694383831834, 'feature_fraction': 0.3551573282280933, 'min_child_samples': 67, 'learning_rate': 0.07062462067119979, 'lambda_l2': 2}. Best is trial 0 with value: 0.5716666666666667.
# [I 2025-07-04 11:24:19,721] Trial 2 finished with value: 0.5495833333333333 and parameters: {'n_estimators': 155, 'max_depth': 7, 'max_bin': 50, 'num_leaves': 35, 'bagging_freq': 1, 'bagging_fraction': 0.5874480513791532, 'feature_fraction': 0.2437492275863192, 'min_child_samples': 68, 'learning_rate': 0.07855489733195431, 'lambda_l2': 0}. Best is trial 0 with value: 0.5716666666666667.
# [I 2025-07-04 11:24:20,846] Trial 3 finished with value: 0.48041666666666666 and parameters: {'n_estimators': 155, 'max_depth': 10, 'max_bin': 50, 'num_leaves': 25, 'bagging_freq': 2, 'bagging_fraction': 0.24494319489543165, 'feature_fraction': 0.8527466936219152, 'min_child_samples': 50, 'learning_rate': 0.0760537349512933, 'lambda_l2': 7}. Best is trial 0 with value: 0.5716666666666667.
# [I 2025-07-04 11:24:22,361] Trial 4 finished with value: 0.5129166666666667 and parameters: {'n_estimators': 155, 'max_depth': 10, 'max_bin': 60, 'num_leaves': 15, 'bagging_freq': 5, 'bagging_fraction': 0.829572724780778, 'feature_fraction': 0.49385599967875127, 'min_child_samples': 25, 'learning_rate': 0.04300613530832881, 'lambda_l2': 8}. Best is trial 0 with value: 0.5716666666666667.
# [I 2025-07-04 11:24:24,329] Trial 5 finished with value: 0.5154166666666666 and parameters: {'n_estimators': 255, 'max_depth': 6, 'max_bin': 50, 'num_leaves': 30, 'bagging_freq': 5, 'bagging_fraction': 0.5449002922472425, 'feature_fraction': 0.5532881130026406, 'min_child_samples': 66, 'learning_rate': 0.0865616545035733, 'lambda_l2': 1}. Best is trial 0 with value: 0.5716666666666667.
# [I 2025-07-04 11:24:25,815] Trial 6 finished with value: 0.4708333333333334 and parameters: {'n_estimators': 205, 'max_depth': 6, 'max_bin': 90, 'num_leaves': 15, 'bagging_freq': 1, 'bagging_fraction': 0.3875111948968829, 'feature_fraction': 0.5468208534086312, 'min_child_samples': 59, 'learning_rate': 0.0628007008539177, 'lambda_l2': 2}. Best is trial 0 with value: 0.5716666666666667.
# [I 2025-07-04 11:24:28,735] Trial 7 finished with value: 0.5783333333333334 and parameters: {'n_estimators': 355, 'max_depth': 7, 'max_bin': 50, 'num_leaves': 20, 'bagging_freq': 5, 'bagging_fraction': 0.7317950191499194, 'feature_fraction': 0.3238785519772445, 'min_child_samples': 77, 'learning_rate': 0.061232112293612306, 'lambda_l2': 2}. Best is trial 7 with value: 0.5783333333333334.
# [I 2025-07-04 11:24:33,782] Trial 8 finished with value: 0.5120833333333333 and parameters: {'n_estimators': 455, 'max_depth': 8, 'max_bin': 80, 'num_leaves': 30, 'bagging_freq': 3, 'bagging_fraction': 0.45458467988493356, 'feature_fraction': 0.884117506101215, 'min_child_samples': 30, 'learning_rate': 0.02274844932806349, 'lambda_l2': 9}. Best is trial 7 with value: 0.5783333333333334.
# [I 2025-07-04 11:24:35,417] Trial 9 finished with value: 0.4983333333333333 and parameters: {'n_estimators': 355, 'max_depth': 6, 'max_bin': 60, 'num_leaves': 15, 'bagging_freq': 5, 'bagging_fraction': 0.8537580586147859, 'feature_fraction': 0.5929829624867773, 'min_child_samples': 77, 'learning_rate': 0.03790850357699818, 'lambda_l2': 3}. Best is trial 7 with value: 0.5783333333333334.
# [I 2025-07-04 11:24:37,383] Trial 10 finished with value: 0.5016666666666667 and parameters: {'n_estimators': 355, 'max_depth': 5, 'max_bin': 90, 'num_leaves': 10, 'bagging_freq': 4, 'bagging_fraction': 0.6816211889999081, 'feature_fraction': 0.2185953184693672, 'min_child_samples': 93, 'learning_rate': 0.09948065970980745, 'lambda_l2': 5}. Best is trial 7 with value: 0.5783333333333334.
# [I 2025-07-04 11:24:40,214] Trial 11 finished with value: 0.5120833333333333 and parameters: {'n_estimators': 505, 'max_depth': 8, 'max_bin': 70, 'num_leaves': 25, 'bagging_freq': 3, 'bagging_fraction': 0.6964125941404922, 'feature_fraction': 0.7193952571862448, 'min_child_samples': 43, 'learning_rate': 0.05290623128380026, 'lambda_l2': 5}. Best is trial 7 with value: 0.5783333333333334.
# [I 2025-07-04 11:24:40,489] Trial 12 finished with value: 0.5379166666666667 and parameters: {'n_estimators': 5, 'max_depth': 7, 'max_bin': 70, 'num_leaves': 20, 'bagging_freq': 2, 'bagging_fraction': 0.5542245691193683, 'feature_fraction': 0.7177157515339534, 'min_child_samples': 88, 'learning_rate': 0.0535978440732037, 'lambda_l2': 10}. Best is trial 7 with value: 0.5783333333333334.
# [I 2025-07-04 11:24:43,886] Trial 13 finished with value: 0.51125 and parameters: {'n_estimators': 405, 'max_depth': 7, 'max_bin': 100, 'num_leaves': 35, 'bagging_freq': 4, 'bagging_fraction': 0.37448675643231677, 'feature_fraction': 0.38777191584478377, 'min_child_samples': 36, 'learning_rate': 0.0895335610884242, 'lambda_l2': 7}. Best is trial 7 with value: 0.5783333333333334.
# [I 2025-07-04 11:24:46,756] Trial 14 finished with value: 0.56 and parameters: {'n_estimators': 505, 'max_depth': 5, 'max_bin': 60, 'num_leaves': 30, 'bagging_freq': 2, 'bagging_fraction': 0.6250347723879305, 'feature_fraction': 0.7210485795257379, 'min_child_samples': 85, 'learning_rate': 0.012799939607552546, 'lambda_l2': 4}. Best is trial 7 with value: 0.5783333333333334.
# [I 2025-07-04 11:24:49,248] Trial 15 finished with value: 0.5358333333333334 and parameters: {'n_estimators': 355, 'max_depth': 8, 'max_bin': 80, 'num_leaves': 20, 'bagging_freq': 4, 'bagging_fraction': 0.7668586733158554, 'feature_fraction': 0.3900814281690992, 'min_child_samples': 21, 'learning_rate': 0.06356131891266315, 'lambda_l2': 7}. Best is trial 7 with value: 0.5783333333333334.
# [I 2025-07-04 11:24:51,236] Trial 16 finished with value: 0.4987499999999999 and parameters: {'n_estimators': 305, 'max_depth': 9, 'max_bin': 70, 'num_leaves': 25, 'bagging_freq': 3, 'bagging_fraction': 0.47046853966895114, 'feature_fraction': 0.6303915690567716, 'min_child_samples': 100, 'learning_rate': 0.040514998225521064, 'lambda_l2': 10}. Best is trial 7 with value: 0.5783333333333334.
# [I 2025-07-04 11:24:53,832] Trial 17 finished with value: 0.5108333333333333 and parameters: {'n_estimators': 455, 'max_depth': 6, 'max_bin': 60, 'num_leaves': 20, 'bagging_freq': 2, 'bagging_fraction': 0.8804244737408786, 'feature_fraction': 0.7942318181070189, 'min_child_samples': 52, 'learning_rate': 0.06311622884670495, 'lambda_l2': 3}. Best is trial 7 with value: 0.5783333333333334.
# [I 2025-07-04 11:24:55,422] Trial 18 finished with value: 0.51625 and parameters: {'n_estimators': 405, 'max_depth': 7, 'max_bin': 80, 'num_leaves': 30, 'bagging_freq': 3, 'bagging_fraction': 0.25584750429235487, 'feature_fraction': 0.29142974395299537, 'min_child_samples': 76, 'learning_rate': 0.04818639493183933, 'lambda_l2': 6}. Best is trial 7 with value: 0.5783333333333334.
# [I 2025-07-04 11:24:58,351] Trial 19 finished with value: 0.5091666666666667 and parameters: {'n_estimators': 255, 'max_depth': 9, 'max_bin': 100, 'num_leaves': 35, 'bagging_freq': 4, 'bagging_fraction': 0.45338182097172597, 'feature_fraction': 0.435964224897646, 'min_child_samples': 39, 'learning_rate': 0.030463738612808468, 'lambda_l2': 0}. Best is trial 7 with value: 0.5783333333333334.
#
# LGBM Optuna Results
# Best Sign Accuracy score (CV): 0.5783333333333334
# Best hyperparameters: {'n_estimators': 355, 'max_depth': 7, 'max_bin': 50, 'num_leaves': 20, 'bagging_freq': 5, 'bagging_fraction': 0.7317950191499194, 'feature_fraction': 0.3238785519772445, 'min_child_samples': 77, 'learning_rate': 0.061232112293612306, 'lambda_l2': 2}

# %%
from lightgbm import LGBMRegressor

params =  {'n_estimators': 355, 
           'max_depth': 7, 
           'max_bin': 50, 
           'num_leaves': 20, 
           'bagging_freq': 5, 
           'bagging_fraction': 0.7317950191499194, 
           'feature_fraction': 0.3238785519772445, 
           'min_child_samples': 77, 
           'learning_rate': 0.061232112293612306, 
           'lambda_l2': 2,
           'device':'gpu',
           'verbose': -1,
           'random_state': 0
           }
lgbm_reg = LGBMRegressor(**study.best_params, device="gpu", verbose=-1, random_state=0)
# lgbm_reg = LGBMRegressor(**params)
lgbm_reg.fit(x_train,y_train)
# Out:
# LGBMRegressor(bagging_fraction=0.7317950191499194, bagging_freq=5, device='gpu',
#               feature_fraction=0.3238785519772445, lambda_l2=2,
#               learning_rate=0.061232112293612306, max_bin=50, max_depth=7,
#               min_child_samples=77, n_estimators=355, num_leaves=20,
#               random_state=0, verbose=-1)

# %%
import numpy as np

def sign_accuracy(y_true, y_pred):
    return np.mean(np.sign(y_true) == np.sign(y_pred))

train_sign_accuracy = sign_accuracy(y_train,lgbm_reg.predict(x_train))
test_sign_accuracy = sign_accuracy(y_test,lgbm_reg.predict(x_test))

print("Train dataset performance: ",train_sign_accuracy)
print("Test dataset performance: ",test_sign_accuracy)
# Out:
# Train dataset performance:  0.8491666666666666
# Test dataset performance:  0.4688888888888889

# %%
def sign_accuracy(y_true, y_pred):
    return np.mean(np.sign(y_true) == np.sign(y_pred))

# 1. Get numeric predictions (already continuous from LightGBM)
train_preds = lgbm_reg.predict(x_train)
test_preds = lgbm_reg.predict(x_test)

# 2. Calculate 90th percentile threshold of abs(preds) on train set
train_abs_preds = np.abs(train_preds)
threshold = np.percentile(train_abs_preds, 90)

# 3. Mask for predictions with abs value above threshold
train_mask = train_abs_preds > threshold
test_mask = np.abs(test_preds) > threshold

# 4. Calculate sign accuracy for only the confident predictions
train_sign_accuracy = sign_accuracy(y_train[train_mask], train_preds[train_mask])
test_sign_accuracy = sign_accuracy(y_test[test_mask], test_preds[test_mask])

print("Train Sign Accuracy (Top 10% most confident preds):", train_sign_accuracy)
print("Test Sign Accuracy (Top 10% most confident preds):", test_sign_accuracy)
# Out:
# Train Sign Accuracy (Top 10% most confident preds): 0.9916666666666667
# Test Sign Accuracy (Top 10% most confident preds): 0.3333333333333333

# %%
from scipy.stats import binom_test

# Example inputs
n_total = 900        # Total number of samples (adjust to your case)
n_correct = int(test_sign_accuracy * n_total)  # Number of correct sign predictions (52% of total)

# Perform one-sided binomial test (greater than 50%)
p_value = binom_test(n_correct, n_total, p=0.5, alternative='greater')

print(f"Sign Accuracy: {n_correct / n_total:.2%}")
print(f"P-value: {p_value:.5f}")
# Out:
# Sign Accuracy: 33.33%
# P-value: 1.00000
# C:\Users\volpe\AppData\Local\Temp\ipykernel_17964\65839734.py:8: DeprecationWarning: 'binom_test' is deprecated in favour of 'binomtest' from version 1.7.0 and will be removed in Scipy 1.12.0.
#   p_value = binom_test(n_correct, n_total, p=0.5, alternative='greater')
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
